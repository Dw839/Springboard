# %% [markdown]
# ## Bayesian methods of hyperparameter optimization

# %% [markdown]
# In addition to the random search and the grid search methods for selecting optimal hyperparameters, we can use Bayesian methods of probabilities to select the optimal hyperparameters for an algorithm.
#
# In this case study, we will be using the BayesianOptimization library to perform hyperparmater tuning. This library has very good documentation which you can find here: https://github.com/fmfn/BayesianOptimization
#
# You will need to install the Bayesian optimization module. Running a cell with an exclamation point in the beginning of the command will run it as a shell command — please do this to install this module from our notebook in the cell below.

# %%
! pip install bayesian-optimization
# Out:
# Requirement already satisfied: bayesian-optimization in c:\users\dwight jones\anaconda3\lib\site-packages (1.4.3)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from bayesian-optimization) (1.24.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from bayesian-optimization) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from bayesian-optimization) (1.3.0)
# Requirement already satisfied: colorama>=0.4.6 in c:\users\dwight jones\anaconda3\lib\site-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dwight jones\anaconda3\lib\site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (2.2.0)

# %%
# !conda config --add channels conda-forge

# %%
# !conda install -y lightgbm
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Dwight Jones\anaconda3
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     lightgbm-3.3.5             |   py39hd77b12b_0         850 KB
#     ------------------------------------------------------------
#                                            Total:         850 KB
#
# The following NEW packages will be INSTALLED:
#
#   lightgbm           pkgs/main/win-64::lightgbm-3.3.5-py39hd77b12b_0 None
#
#
#
# Downloading and Extracting Packages
#
# lightgbm-3.3.5       | 850 KB    |            |   0%
# lightgbm-3.3.5       | 850 KB    | 1          |   2%
# lightgbm-3.3.5       | 850 KB    | #8         |  19%
# lightgbm-3.3.5       | 850 KB    | ###2       |  32%
# lightgbm-3.3.5       | 850 KB    | ####5      |  45%
# lightgbm-3.3.5       | 850 KB    | #####8     |  58%
# lightgbm-3.3.5       | 850 KB    | #######3   |  73%
# lightgbm-3.3.5       | 850 KB    | ########6  |  87%
# lightgbm-3.3.5       | 850 KB    | #########9 | 100%
# lightgbm-3.3.5       | 850 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
conda update -n base -c defaults conda
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Dwight Jones\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiofiles-22.1.0            |   py39haa95532_0          25 KB
#     aiosqlite-0.18.0           |   py39haa95532_0          34 KB
#     anaconda-anon-usage-0.4.3  | py39hfc23b7f_100          24 KB
#     attrs-23.1.0               |   py39haa95532_0         143 KB
#     boltons-23.0.0             |   py39haa95532_0         421 KB
#     boost-cpp-1.82.0           |       h59b6b97_2          11 KB
#     conda-23.9.0               |   py39haa95532_0         978 KB
#     conda-build-3.27.0         |   py39haa95532_0         596 KB
#     conda-index-0.3.0          |   py39haa95532_0         202 KB
#     flask-2.2.2                |   py39haa95532_0         165 KB
#     huggingface_hub-0.17.3     |   py39haa95532_0         369 KB
#     imageio-2.31.4             |   py39haa95532_0         479 KB
#     jinja2-3.1.2               |   py39haa95532_0         211 KB
#     jsonpatch-1.32             |     pyhd3eb1b0_0          15 KB
#     jsonpointer-2.1            |     pyhd3eb1b0_0           9 KB
#     jupyter_events-0.6.3       |   py39haa95532_0          92 KB
#     jupyter_server-2.5.0       |   py39haa95532_0         486 KB
#     jupyter_server_fileid-0.9.0|   py39haa95532_0          48 KB
#     jupyter_server_terminals-0.4.4|   py39haa95532_1          25 KB
#     jupyter_server_ydoc-0.8.0  |   py39haa95532_1          22 KB
#     jupyter_ydoc-0.2.4         |   py39haa95532_0          15 KB
#     jupyterlab-3.6.3           |   py39haa95532_0         4.3 MB
#     jupyterlab_server-2.22.0   |   py39haa95532_0          83 KB
#     libboost-1.82.0            |       h3399ecb_2        23.1 MB
#     libdeflate-1.17            |       h2bbff1b_1         153 KB
#     llvmlite-0.41.0            |   py39hf2fb9eb_0        18.5 MB
#     markupsafe-2.1.1           |   py39h2bbff1b_0          26 KB
#     nbconvert-6.5.4            |   py39haa95532_0         537 KB
#     numba-0.58.0               |   py39h4ed8f06_0         4.3 MB
#     numexpr-2.8.7              |   py39h2cd9be0_0         132 KB
#     pandas-2.0.3               |   py39h4ed8f06_0         9.8 MB
#     pillow-10.0.1              |   py39h045eedc_0         781 KB
#     pycosat-0.6.6              |   py39h2bbff1b_0          84 KB
#     pyodbc-4.0.39              |   py39hd77b12b_0          67 KB
#     python-json-logger-2.0.7   |   py39haa95532_0          16 KB
#     python-tzdata-2023.3       |     pyhd3eb1b0_0         140 KB
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     queuelib-1.6.2             |   py39haa95532_0          28 KB
#     regex-2023.10.3            |   py39h2bbff1b_0         326 KB
#     rfc3339-validator-0.1.4    |   py39haa95532_0          10 KB
#     rfc3986-validator-0.1.1    |   py39haa95532_0          10 KB
#     ruamel.yaml-0.17.21        |   py39h2bbff1b_0         174 KB
#     ruamel.yaml.clib-0.2.7     |   py39ha55989b_2         102 KB  conda-forge
#     scipy-1.11.3               |   py39h309d312_0        19.2 MB
#     soupsieve-2.5              |   py39haa95532_0          70 KB
#     sqlalchemy-2.0.21          |   py39h2bbff1b_0         3.0 MB
#     tokenizers-0.13.3          |   py39h49fca51_0         3.0 MB
#     tornado-6.3.3              |   py39h2bbff1b_0         638 KB
#     ucrt-10.0.20348.0          |       haa95532_0         531 KB
#     vc14_runtime-14.36.32532   |      hdcecf7f_17         722 KB  conda-forge
#     vs2015_runtime-14.36.32532 |      h05e6639_17          17 KB  conda-forge
#     werkzeug-2.2.3             |   py39haa95532_0         341 KB
#     wheel-0.41.2               |   py39haa95532_0         126 KB
#     y-py-0.5.9                 |   py39hb6bf4ef_0        61.5 MB
#     ypy-websocket-0.8.2        |   py39haa95532_0          26 KB
#     zict-3.0.0                 |   py39haa95532_0          91 KB
#     ------------------------------------------------------------
#                                            Total:       156.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiofiles           pkgs/main/win-64::aiofiles-22.1.0-py39haa95532_0 None
#   aiosqlite          pkgs/main/win-64::aiosqlite-0.18.0-py39haa95532_0 None
#   boltons            pkgs/main/win-64::boltons-23.0.0-py39haa95532_0 None
#   conda-index        pkgs/main/win-64::conda-index-0.3.0-py39haa95532_0 None
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd3eb1b0_0 None
#   jsonpointer        pkgs/main/noarch::jsonpointer-2.1-pyhd3eb1b0_0 None
#   jupyter_events     pkgs/main/win-64::jupyter_events-0.6.3-py39haa95532_0 None
#   jupyter_server_fi~ pkgs/main/win-64::jupyter_server_fileid-0.9.0-py39haa95532_0 None
#   jupyter_server_te~ pkgs/main/win-64::jupyter_server_terminals-0.4.4-py39haa95532_1 None
#   jupyter_server_yd~ pkgs/main/win-64::jupyter_server_ydoc-0.8.0-py39haa95532_1 None
#   jupyter_ydoc       pkgs/main/win-64::jupyter_ydoc-0.2.4-py39haa95532_0 None
#   python-json-logger pkgs/main/win-64::python-json-logger-2.0.7-py39haa95532_0 None
#   python-tzdata      pkgs/main/noarch::python-tzdata-2023.3-pyhd3eb1b0_0 None
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39 None
#   rfc3339-validator  pkgs/main/win-64::rfc3339-validator-0.1.4-py39haa95532_0 None
#   rfc3986-validator  pkgs/main/win-64::rfc3986-validator-0.1.1-py39haa95532_0 None
#   ruamel.yaml        pkgs/main/win-64::ruamel.yaml-0.17.21-py39h2bbff1b_0 None
#   ruamel.yaml.clib   conda-forge/win-64::ruamel.yaml.clib-0.2.7-py39ha55989b_2 None
#   ucrt               pkgs/main/win-64::ucrt-10.0.20348.0-haa95532_0 None
#   vc14_runtime       conda-forge/win-64::vc14_runtime-14.36.32532-hdcecf7f_17 None
#   y-py               pkgs/main/win-64::y-py-0.5.9-py39hb6bf4ef_0 None
#   ypy-websocket      pkgs/main/win-64::ypy-websocket-0.8.2-py39haa95532_0 None
#
# The following packages will be REMOVED:
#
#   dataclasses-0.8-pyh6d0b6a4_7
#   glob2-0.7-pyhd3eb1b0_0
#   ruamel_yaml-0.15.100-py39h2bbff1b_0
#   testpath-0.6.0-py39haa95532_0
#
# The following packages will be UPDATED:
#
#   anaconda-anon-usa~                   0.4.1-py39h8ddfbff_0 --> 0.4.3-py39hfc23b7f_100 None
#   attrs                               22.1.0-py39haa95532_0 --> 23.1.0-py39haa95532_0 None
#   boost-cpp                               1.82.0-h59b6b97_1 --> 1.82.0-h59b6b97_2 None
#   ca-certificates    conda-forge::ca-certificates-2023.7.2~ --> pkgs/main::ca-certificates-2023.08.22-haa95532_0 None
#   conda                               22.9.0-py39haa95532_0 --> 23.9.0-py39haa95532_0 None
#   conda-build                         3.22.0-py39haa95532_0 --> 3.27.0-py39haa95532_0 None
#   flask              pkgs/main/noarch::flask-1.1.2-pyhd3eb~ --> pkgs/main/win-64::flask-2.2.2-py39haa95532_0 None
#   huggingface_hub                     0.15.1-py39haa95532_0 --> 0.17.3-py39haa95532_0 None
#   imageio                             2.26.0-py39haa95532_0 --> 2.31.4-py39haa95532_0 None
#   jinja2             pkgs/main/noarch::jinja2-2.11.3-pyhd3~ --> pkgs/main/win-64::jinja2-3.1.2-py39haa95532_0 None
#   jupyter_server                      1.23.4-py39haa95532_0 --> 2.5.0-py39haa95532_0 None
#   jupyterlab                           3.4.4-py39haa95532_0 --> 3.6.3-py39haa95532_0 None
#   jupyterlab_server  pkgs/main/noarch::jupyterlab_server-2~ --> pkgs/main/win-64::jupyterlab_server-2.22.0-py39haa95532_0 None
#   libboost                                1.82.0-hae598e9_1 --> 1.82.0-h3399ecb_2 None
#   libdeflate                                1.17-h2bbff1b_0 --> 1.17-h2bbff1b_1 None
#   llvmlite                            0.40.0-py39hf2fb9eb_0 --> 0.41.0-py39hf2fb9eb_0 None
#   markupsafe                           2.0.1-py39h2bbff1b_0 --> 2.1.1-py39h2bbff1b_0 None
#   nbconvert                            6.4.4-py39haa95532_0 --> 6.5.4-py39haa95532_0 None
#   numba                               0.57.1-py39h4ed8f06_0 --> 0.58.0-py39h4ed8f06_0 None
#   numexpr                              2.8.4-py39h7b80656_1 --> 2.8.7-py39h2cd9be0_0 None
#   pandas                               1.4.4-py39hd77b12b_0 --> 2.0.3-py39h4ed8f06_0 None
#   pillow                               9.4.0-py39hd77b12b_1 --> 10.0.1-py39h045eedc_0 None
#   pycosat                              0.6.4-py39h2bbff1b_0 --> 0.6.6-py39h2bbff1b_0 None
#   pyodbc                              4.0.34-py39hd77b12b_0 --> 4.0.39-py39hd77b12b_0 None
#   queuelib                             1.5.0-py39haa95532_0 --> 1.6.2-py39haa95532_0 None
#   regex                             2022.7.9-py39h2bbff1b_0 --> 2023.10.3-py39h2bbff1b_0 None
#   scipy                               1.11.1-py39h309d312_0 --> 1.11.3-py39h309d312_0 None
#   soupsieve                              2.4-py39haa95532_0 --> 2.5-py39haa95532_0 None
#   sqlalchemy                          1.4.39-py39h2bbff1b_0 --> 2.0.21-py39h2bbff1b_0 None
#   tokenizers                          0.13.2-py39h49fca51_1 --> 0.13.3-py39h49fca51_0 None
#   tornado                              6.3.2-py39h2bbff1b_0 --> 6.3.3-py39h2bbff1b_0 None
#   vs2015_runtime     pkgs/main::vs2015_runtime-14.27.29016~ --> conda-forge::vs2015_runtime-14.36.32532-h05e6639_17 None
#   werkzeug           pkgs/main/noarch::werkzeug-2.0.3-pyhd~ --> pkgs/main/win-64::werkzeug-2.2.3-py39haa95532_0 None
#   wheel                               0.38.4-py39haa95532_0 --> 0.41.2-py39haa95532_0 None
#   zict                                 2.2.0-py39haa95532_0 --> 3.0.0-py39haa95532_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2023.7.22~ --> pkgs/main/win-64::certifi-2023.7.22-py39haa95532_0 None
#
#
#
# Downloading and Extracting Packages
#
# jupyter_server_ydoc- | 22 KB     |            |   0%
# jupyter_server_ydoc- | 22 KB     | #######1   |  72%
# jupyter_server_ydoc- | 22 KB     | ########## | 100%
# jupyter_server_ydoc- | 22 KB     | ########## | 100%
#
# vc14_runtime-14.36.3 | 722 KB    |            |   0%
# vc14_runtime-14.36.3 | 722 KB    | 2          |   2%
# vc14_runtime-14.36.3 | 722 KB    | #1         |  11%
# vc14_runtime-14.36.3 | 722 KB    | ##6        |  27%
# vc14_runtime-14.36.3 | 722 KB    | ####6      |  47%
# vc14_runtime-14.36.3 | 722 KB    | #####9     |  60%
# vc14_runtime-14.36.3 | 722 KB    | #######    |  71%
# vc14_runtime-14.36.3 | 722 KB    | #######9   |  80%
# vc14_runtime-14.36.3 | 722 KB    | ########8  |  89%
# vc14_runtime-14.36.3 | 722 KB    | ########## | 100%
# vc14_runtime-14.36.3 | 722 KB    | ########## | 100%
#
# tokenizers-0.13.3    | 3.0 MB    |            |   0%
# tokenizers-0.13.3    | 3.0 MB    | 3          |   3%
# tokenizers-0.13.3    | 3.0 MB    | 8          |   8%
# tokenizers-0.13.3    | 3.0 MB    | #3         |  13%
# tokenizers-0.13.3    | 3.0 MB    | #9         |  20%
# tokenizers-0.13.3    | 3.0 MB    | ##5        |  26%
# tokenizers-0.13.3    | 3.0 MB    | ###        |  31%
# tokenizers-0.13.3    | 3.0 MB    | ###7       |  38%
# tokenizers-0.13.3    | 3.0 MB    | ####4      |  44%
# tokenizers-0.13.3    | 3.0 MB    | #####      |  50%
# tokenizers-0.13.3    | 3.0 MB    | #####6     |  56%
# tokenizers-0.13.3    | 3.0 MB    | ######2    |  62%
# tokenizers-0.13.3    | 3.0 MB    | ######8    |  68%
# tokenizers-0.13.3    | 3.0 MB    | #######3   |  73%
# tokenizers-0.13.3    | 3.0 MB    | #######8   |  79%
# tokenizers-0.13.3    | 3.0 MB    | ########4  |  84%
# tokenizers-0.13.3    | 3.0 MB    | ########8  |  88%
# tokenizers-0.13.3    | 3.0 MB    | #########1 |  92%
# tokenizers-0.13.3    | 3.0 MB    | #########6 |  96%
# tokenizers-0.13.3    | 3.0 MB    | ########## | 100%
#
# python-json-logger-2 | 16 KB     |            |   0%
# python-json-logger-2 | 16 KB     | ########## | 100%
# python-json-logger-2 | 16 KB     | ########## | 100%
#
# ucrt-10.0.20348.0    | 531 KB    |            |   0%
# ucrt-10.0.20348.0    | 531 KB    | 9          |   9%
# ucrt-10.0.20348.0    | 531 KB    | ####5      |  45%
# ucrt-10.0.20348.0    | 531 KB    | ######6    |  66%
# ucrt-10.0.20348.0    | 531 KB    | #########6 |  97%
# ucrt-10.0.20348.0    | 531 KB    | ########## | 100%
#
# wheel-0.41.2         | 126 KB    |            |   0%
# wheel-0.41.2         | 126 KB    | #####      |  51%
# wheel-0.41.2         | 126 KB    | ########## | 100%
# wheel-0.41.2         | 126 KB    | ########## | 100%
#
# python_abi-3.9       | 4 KB      |            |   0%
# python_abi-3.9       | 4 KB      | ########## | 100%
# python_abi-3.9       | 4 KB      | ########## | 100%
#
# ruamel.yaml-0.17.21  | 174 KB    |            |   0%
# ruamel.yaml-0.17.21  | 174 KB    | ###6       |  37%
# ruamel.yaml-0.17.21  | 174 KB    | #######3   |  74%
# ruamel.yaml-0.17.21  | 174 KB    | ########## | 100%
#
# numexpr-2.8.7        | 132 KB    |            |   0%
# numexpr-2.8.7        | 132 KB    | ######     |  60%
# numexpr-2.8.7        | 132 KB    | ########## | 100%
#
# vs2015_runtime-14.36 | 17 KB     |            |   0%
# vs2015_runtime-14.36 | 17 KB     | ########## | 100%
# vs2015_runtime-14.36 | 17 KB     | ########## | 100%
#
# anaconda-anon-usage- | 24 KB     |            |   0%
# anaconda-anon-usage- | 24 KB     | ########## | 100%
# anaconda-anon-usage- | 24 KB     | ########## | 100%
#
# jupyter_events-0.6.3 | 92 KB     |            |   0%
# jupyter_events-0.6.3 | 92 KB     | #7         |  17%
# jupyter_events-0.6.3 | 92 KB     | ########## | 100%
# jupyter_events-0.6.3 | 92 KB     | ########## | 100%
#
# python-tzdata-2023.3 | 140 KB    |            |   0%
# python-tzdata-2023.3 | 140 KB    | ####5      |  46%
# python-tzdata-2023.3 | 140 KB    | ########## | 100%
# python-tzdata-2023.3 | 140 KB    | ########## | 100%
#
# markupsafe-2.1.1     | 26 KB     |            |   0%
# markupsafe-2.1.1     | 26 KB     | ########## | 100%
# markupsafe-2.1.1     | 26 KB     | ########## | 100%
#
# scipy-1.11.3         | 19.2 MB   |            |   0%
# scipy-1.11.3         | 19.2 MB   |            |   0%
# scipy-1.11.3         | 19.2 MB   | 1          |   1%
# scipy-1.11.3         | 19.2 MB   | 1          |   2%
# scipy-1.11.3         | 19.2 MB   | 2          |   3%
# scipy-1.11.3         | 19.2 MB   | 3          |   3%
# scipy-1.11.3         | 19.2 MB   | 3          |   4%
# scipy-1.11.3         | 19.2 MB   | 4          |   5%
# scipy-1.11.3         | 19.2 MB   | 5          |   6%
# scipy-1.11.3         | 19.2 MB   | 6          |   6%
# scipy-1.11.3         | 19.2 MB   | 7          |   7%
# scipy-1.11.3         | 19.2 MB   | 7          |   8%
# scipy-1.11.3         | 19.2 MB   | 8          |   9%
# scipy-1.11.3         | 19.2 MB   | 9          |   9%
# scipy-1.11.3         | 19.2 MB   | 9          |  10%
# scipy-1.11.3         | 19.2 MB   | #          |  11%
# scipy-1.11.3         | 19.2 MB   | #1         |  11%
# scipy-1.11.3         | 19.2 MB   | #1         |  12%
# scipy-1.11.3         | 19.2 MB   | #2         |  13%
# scipy-1.11.3         | 19.2 MB   | #3         |  13%
# scipy-1.11.3         | 19.2 MB   | #4         |  14%
# scipy-1.11.3         | 19.2 MB   | #5         |  15%
# scipy-1.11.3         | 19.2 MB   | #5         |  16%
# scipy-1.11.3         | 19.2 MB   | #6         |  17%
# scipy-1.11.3         | 19.2 MB   | #7         |  18%
# scipy-1.11.3         | 19.2 MB   | #8         |  19%
# scipy-1.11.3         | 19.2 MB   | #9         |  19%
# scipy-1.11.3         | 19.2 MB   | ##         |  20%
# scipy-1.11.3         | 19.2 MB   | ##1        |  21%
# scipy-1.11.3         | 19.2 MB   | ##2        |  22%
# scipy-1.11.3         | 19.2 MB   | ##3        |  23%
# scipy-1.11.3         | 19.2 MB   | ##4        |  24%
# scipy-1.11.3         | 19.2 MB   | ##5        |  25%
# scipy-1.11.3         | 19.2 MB   | ##6        |  26%
# scipy-1.11.3         | 19.2 MB   | ##6        |  27%
# scipy-1.11.3         | 19.2 MB   | ##7        |  28%
# scipy-1.11.3         | 19.2 MB   | ##8        |  29%
# scipy-1.11.3         | 19.2 MB   | ##9        |  30%
# scipy-1.11.3         | 19.2 MB   | ###        |  31%
# scipy-1.11.3         | 19.2 MB   | ###1       |  32%
# scipy-1.11.3         | 19.2 MB   | ###2       |  33%
# scipy-1.11.3         | 19.2 MB   | ###3       |  33%
# scipy-1.11.3         | 19.2 MB   | ###4       |  34%
# scipy-1.11.3         | 19.2 MB   | ###5       |  35%
# scipy-1.11.3         | 19.2 MB   | ###5       |  36%
# scipy-1.11.3         | 19.2 MB   | ###6       |  37%
# scipy-1.11.3         | 19.2 MB   | ###7       |  38%
# scipy-1.11.3         | 19.2 MB   | ###8       |  38%
# scipy-1.11.3         | 19.2 MB   | ###8       |  39%
# scipy-1.11.3         | 19.2 MB   | ###9       |  39%
# scipy-1.11.3         | 19.2 MB   | ###9       |  40%
# scipy-1.11.3         | 19.2 MB   | ####       |  41%
# scipy-1.11.3         | 19.2 MB   | ####1      |  42%
# scipy-1.11.3         | 19.2 MB   | ####2      |  43%
# scipy-1.11.3         | 19.2 MB   | ####3      |  44%
# scipy-1.11.3         | 19.2 MB   | ####4      |  44%
# scipy-1.11.3         | 19.2 MB   | ####5      |  45%
# scipy-1.11.3         | 19.2 MB   | ####6      |  46%
# scipy-1.11.3         | 19.2 MB   | ####7      |  47%
# scipy-1.11.3         | 19.2 MB   | ####8      |  48%
# scipy-1.11.3         | 19.2 MB   | ####9      |  49%
# scipy-1.11.3         | 19.2 MB   | ####9      |  50%
# scipy-1.11.3         | 19.2 MB   | #####      |  51%
# scipy-1.11.3         | 19.2 MB   | #####1     |  52%
# scipy-1.11.3         | 19.2 MB   | #####2     |  53%
# scipy-1.11.3         | 19.2 MB   | #####3     |  54%
# scipy-1.11.3         | 19.2 MB   | #####4     |  55%
# scipy-1.11.3         | 19.2 MB   | #####5     |  56%
# scipy-1.11.3         | 19.2 MB   | #####6     |  57%
# scipy-1.11.3         | 19.2 MB   | #####7     |  58%
# scipy-1.11.3         | 19.2 MB   | #####8     |  58%
# scipy-1.11.3         | 19.2 MB   | #####9     |  59%
# scipy-1.11.3         | 19.2 MB   | #####9     |  60%
# scipy-1.11.3         | 19.2 MB   | ######     |  61%
# scipy-1.11.3         | 19.2 MB   | ######1    |  62%
# scipy-1.11.3         | 19.2 MB   | ######2    |  63%
# scipy-1.11.3         | 19.2 MB   | ######3    |  64%
# scipy-1.11.3         | 19.2 MB   | ######4    |  64%
# scipy-1.11.3         | 19.2 MB   | ######5    |  65%
# scipy-1.11.3         | 19.2 MB   | ######6    |  66%
# scipy-1.11.3         | 19.2 MB   | ######7    |  67%
# scipy-1.11.3         | 19.2 MB   | ######8    |  69%
# scipy-1.11.3         | 19.2 MB   | ######9    |  70%
# scipy-1.11.3         | 19.2 MB   | #######    |  70%
# scipy-1.11.3         | 19.2 MB   | #######1   |  71%
# scipy-1.11.3         | 19.2 MB   | #######2   |  72%
# scipy-1.11.3         | 19.2 MB   | #######3   |  73%
# scipy-1.11.3         | 19.2 MB   | #######4   |  74%
# scipy-1.11.3         | 19.2 MB   | #######5   |  75%
# scipy-1.11.3         | 19.2 MB   | #######5   |  76%
# scipy-1.11.3         | 19.2 MB   | #######6   |  77%
# scipy-1.11.3         | 19.2 MB   | #######8   |  78%
# scipy-1.11.3         | 19.2 MB   | #######9   |  79%
# scipy-1.11.3         | 19.2 MB   | ########   |  80%
# scipy-1.11.3         | 19.2 MB   | ########1  |  81%
# scipy-1.11.3         | 19.2 MB   | ########2  |  82%
# scipy-1.11.3         | 19.2 MB   | ########3  |  83%
# scipy-1.11.3         | 19.2 MB   | ########4  |  84%
# scipy-1.11.3         | 19.2 MB   | ########5  |  86%
# scipy-1.11.3         | 19.2 MB   | ########6  |  87%
# scipy-1.11.3         | 19.2 MB   | ########7  |  88%
# scipy-1.11.3         | 19.2 MB   | ########9  |  89%
# scipy-1.11.3         | 19.2 MB   | #########  |  90%
# scipy-1.11.3         | 19.2 MB   | #########1 |  91%
# scipy-1.11.3         | 19.2 MB   | #########2 |  92%
# scipy-1.11.3         | 19.2 MB   | #########3 |  93%
# scipy-1.11.3         | 19.2 MB   | #########3 |  94%
# scipy-1.11.3         | 19.2 MB   | #########4 |  94%
# scipy-1.11.3         | 19.2 MB   | #########5 |  95%
# scipy-1.11.3         | 19.2 MB   | #########6 |  96%
# scipy-1.11.3         | 19.2 MB   | #########7 |  97%
# scipy-1.11.3         | 19.2 MB   | #########8 |  98%
# scipy-1.11.3         | 19.2 MB   | #########9 |  99%
# scipy-1.11.3         | 19.2 MB   | ########## | 100%
# scipy-1.11.3         | 19.2 MB   | ########## | 100%
#
# conda-build-3.27.0   | 596 KB    |            |   0%
# conda-build-3.27.0   | 596 KB    | 5          |   5%
# conda-build-3.27.0   | 596 KB    | ###7       |  38%
# conda-build-3.27.0   | 596 KB    | #####9     |  59%
# conda-build-3.27.0   | 596 KB    | #######5   |  75%
# conda-build-3.27.0   | 596 KB    | #########6 |  97%
# conda-build-3.27.0   | 596 KB    | ########## | 100%
#
# soupsieve-2.5        | 70 KB     |            |   0%
# soupsieve-2.5        | 70 KB     | ########## | 100%
# soupsieve-2.5        | 70 KB     | ########## | 100%
#
# rfc3339-validator-0. | 10 KB     |            |   0%
# rfc3339-validator-0. | 10 KB     | ########## | 100%
# rfc3339-validator-0. | 10 KB     | ########## | 100%
#
# attrs-23.1.0         | 143 KB    |            |   0%
# attrs-23.1.0         | 143 KB    | ####4      |  45%
# attrs-23.1.0         | 143 KB    | ########## | 100%
# attrs-23.1.0         | 143 KB    | ########## | 100%
#
# llvmlite-0.41.0      | 18.5 MB   |            |   0%
# llvmlite-0.41.0      | 18.5 MB   |            |   0%
# llvmlite-0.41.0      | 18.5 MB   | 1          |   1%
# llvmlite-0.41.0      | 18.5 MB   | 1          |   2%
# llvmlite-0.41.0      | 18.5 MB   | 2          |   3%
# llvmlite-0.41.0      | 18.5 MB   | 3          |   4%
# llvmlite-0.41.0      | 18.5 MB   | 4          |   5%
# llvmlite-0.41.0      | 18.5 MB   | 5          |   5%
# llvmlite-0.41.0      | 18.5 MB   | 6          |   6%
# llvmlite-0.41.0      | 18.5 MB   | 7          |   7%
# llvmlite-0.41.0      | 18.5 MB   | 8          |   8%
# llvmlite-0.41.0      | 18.5 MB   | 9          |   9%
# llvmlite-0.41.0      | 18.5 MB   | #          |  10%
# llvmlite-0.41.0      | 18.5 MB   | #1         |  11%
# llvmlite-0.41.0      | 18.5 MB   | #1         |  12%
# llvmlite-0.41.0      | 18.5 MB   | #2         |  13%
# llvmlite-0.41.0      | 18.5 MB   | #3         |  14%
# llvmlite-0.41.0      | 18.5 MB   | #4         |  15%
# llvmlite-0.41.0      | 18.5 MB   | #5         |  15%
# llvmlite-0.41.0      | 18.5 MB   | #6         |  16%
# llvmlite-0.41.0      | 18.5 MB   | #6         |  17%
# llvmlite-0.41.0      | 18.5 MB   | #7         |  18%
# llvmlite-0.41.0      | 18.5 MB   | #8         |  18%
# llvmlite-0.41.0      | 18.5 MB   | #9         |  19%
# llvmlite-0.41.0      | 18.5 MB   | ##         |  20%
# llvmlite-0.41.0      | 18.5 MB   | ##1        |  21%
# llvmlite-0.41.0      | 18.5 MB   | ##2        |  22%
# llvmlite-0.41.0      | 18.5 MB   | ##3        |  23%
# llvmlite-0.41.0      | 18.5 MB   | ##4        |  24%
# llvmlite-0.41.0      | 18.5 MB   | ##5        |  25%
# llvmlite-0.41.0      | 18.5 MB   | ##6        |  26%
# llvmlite-0.41.0      | 18.5 MB   | ##7        |  27%
# llvmlite-0.41.0      | 18.5 MB   | ##8        |  28%
# llvmlite-0.41.0      | 18.5 MB   | ##9        |  29%
# llvmlite-0.41.0      | 18.5 MB   | ###        |  30%
# llvmlite-0.41.0      | 18.5 MB   | ###1       |  31%
# llvmlite-0.41.0      | 18.5 MB   | ###2       |  32%
# llvmlite-0.41.0      | 18.5 MB   | ###3       |  33%
# llvmlite-0.41.0      | 18.5 MB   | ###4       |  35%
# llvmlite-0.41.0      | 18.5 MB   | ###5       |  36%
# llvmlite-0.41.0      | 18.5 MB   | ###6       |  37%
# llvmlite-0.41.0      | 18.5 MB   | ###7       |  38%
# llvmlite-0.41.0      | 18.5 MB   | ###8       |  39%
# llvmlite-0.41.0      | 18.5 MB   | ###9       |  40%
# llvmlite-0.41.0      | 18.5 MB   | ####       |  40%
# llvmlite-0.41.0      | 18.5 MB   | ####1      |  41%
# llvmlite-0.41.0      | 18.5 MB   | ####1      |  42%
# llvmlite-0.41.0      | 18.5 MB   | ####2      |  42%
# llvmlite-0.41.0      | 18.5 MB   | ####2      |  43%
# llvmlite-0.41.0      | 18.5 MB   | ####3      |  43%
# llvmlite-0.41.0      | 18.5 MB   | ####3      |  44%
# llvmlite-0.41.0      | 18.5 MB   | ####4      |  44%
# llvmlite-0.41.0      | 18.5 MB   | ####5      |  45%
# llvmlite-0.41.0      | 18.5 MB   | ####5      |  46%
# llvmlite-0.41.0      | 18.5 MB   | ####6      |  47%
# llvmlite-0.41.0      | 18.5 MB   | ####7      |  47%
# llvmlite-0.41.0      | 18.5 MB   | ####7      |  48%
# llvmlite-0.41.0      | 18.5 MB   | ####8      |  49%
# llvmlite-0.41.0      | 18.5 MB   | ####9      |  49%
# llvmlite-0.41.0      | 18.5 MB   | #####      |  50%
# llvmlite-0.41.0      | 18.5 MB   | #####      |  51%
# llvmlite-0.41.0      | 18.5 MB   | #####2     |  52%
# llvmlite-0.41.0      | 18.5 MB   | #####3     |  53%
# llvmlite-0.41.0      | 18.5 MB   | #####4     |  54%
# llvmlite-0.41.0      | 18.5 MB   | #####5     |  55%
# llvmlite-0.41.0      | 18.5 MB   | #####5     |  56%
# llvmlite-0.41.0      | 18.5 MB   | #####6     |  57%
# llvmlite-0.41.0      | 18.5 MB   | #####7     |  58%
# llvmlite-0.41.0      | 18.5 MB   | #####8     |  59%
# llvmlite-0.41.0      | 18.5 MB   | #####9     |  60%
# llvmlite-0.41.0      | 18.5 MB   | ######     |  61%
# llvmlite-0.41.0      | 18.5 MB   | ######1    |  61%
# llvmlite-0.41.0      | 18.5 MB   | ######2    |  62%
# llvmlite-0.41.0      | 18.5 MB   | ######2    |  63%
# llvmlite-0.41.0      | 18.5 MB   | ######3    |  64%
# llvmlite-0.41.0      | 18.5 MB   | ######4    |  64%
# llvmlite-0.41.0      | 18.5 MB   | ######5    |  65%
# llvmlite-0.41.0      | 18.5 MB   | ######5    |  66%
# llvmlite-0.41.0      | 18.5 MB   | ######6    |  66%
# llvmlite-0.41.0      | 18.5 MB   | ######6    |  67%
# llvmlite-0.41.0      | 18.5 MB   | ######7    |  67%
# llvmlite-0.41.0      | 18.5 MB   | ######8    |  68%
# llvmlite-0.41.0      | 18.5 MB   | ######9    |  69%
# llvmlite-0.41.0      | 18.5 MB   | #######    |  70%
# llvmlite-0.41.0      | 18.5 MB   | #######1   |  71%
# llvmlite-0.41.0      | 18.5 MB   | #######1   |  72%
# llvmlite-0.41.0      | 18.5 MB   | #######2   |  73%
# llvmlite-0.41.0      | 18.5 MB   | #######3   |  74%
# llvmlite-0.41.0      | 18.5 MB   | #######4   |  74%
# llvmlite-0.41.0      | 18.5 MB   | #######5   |  75%
# llvmlite-0.41.0      | 18.5 MB   | #######5   |  76%
# llvmlite-0.41.0      | 18.5 MB   | #######6   |  77%
# llvmlite-0.41.0      | 18.5 MB   | #######7   |  77%
# llvmlite-0.41.0      | 18.5 MB   | #######8   |  78%
# llvmlite-0.41.0      | 18.5 MB   | #######8   |  79%
# llvmlite-0.41.0      | 18.5 MB   | #######9   |  80%
# llvmlite-0.41.0      | 18.5 MB   | ########   |  80%
# llvmlite-0.41.0      | 18.5 MB   | ########1  |  81%
# llvmlite-0.41.0      | 18.5 MB   | ########2  |  82%
# llvmlite-0.41.0      | 18.5 MB   | ########3  |  83%
# llvmlite-0.41.0      | 18.5 MB   | ########3  |  84%
# llvmlite-0.41.0      | 18.5 MB   | ########4  |  85%
# llvmlite-0.41.0      | 18.5 MB   | ########5  |  86%
# llvmlite-0.41.0      | 18.5 MB   | ########6  |  87%
# llvmlite-0.41.0      | 18.5 MB   | ########7  |  87%
# llvmlite-0.41.0      | 18.5 MB   | ########8  |  88%
# llvmlite-0.41.0      | 18.5 MB   | ########9  |  89%
# llvmlite-0.41.0      | 18.5 MB   | #########  |  90%
# llvmlite-0.41.0      | 18.5 MB   | #########1 |  91%
# llvmlite-0.41.0      | 18.5 MB   | #########2 |  93%
# llvmlite-0.41.0      | 18.5 MB   | #########3 |  94%
# llvmlite-0.41.0      | 18.5 MB   | #########4 |  94%
# llvmlite-0.41.0      | 18.5 MB   | #########5 |  95%
# llvmlite-0.41.0      | 18.5 MB   | #########6 |  96%
# llvmlite-0.41.0      | 18.5 MB   | #########7 |  97%
# llvmlite-0.41.0      | 18.5 MB   | #########7 |  98%
# llvmlite-0.41.0      | 18.5 MB   | #########8 |  99%
# llvmlite-0.41.0      | 18.5 MB   | #########9 | 100%
# llvmlite-0.41.0      | 18.5 MB   | ########## | 100%
#
# libdeflate-1.17      | 153 KB    |            |   0%
# libdeflate-1.17      | 153 KB    | ####1      |  42%
# libdeflate-1.17      | 153 KB    | ########## | 100%
# libdeflate-1.17      | 153 KB    | ########## | 100%
#
# ruamel.yaml.clib-0.2 | 102 KB    |            |   0%
# ruamel.yaml.clib-0.2 | 102 KB    | ######2    |  63%
# ruamel.yaml.clib-0.2 | 102 KB    | ########## | 100%
#
# huggingface_hub-0.17 | 369 KB    |            |   0%
# huggingface_hub-0.17 | 369 KB    | ##6        |  26%
# huggingface_hub-0.17 | 369 KB    | ######9    |  69%
# huggingface_hub-0.17 | 369 KB    | ########## | 100%
# huggingface_hub-0.17 | 369 KB    | ########## | 100%
#
# numba-0.58.0         | 4.3 MB    |            |   0%
# numba-0.58.0         | 4.3 MB    | 1          |   2%
# numba-0.58.0         | 4.3 MB    | 5          |   6%
# numba-0.58.0         | 4.3 MB    | #          |  10%
# numba-0.58.0         | 4.3 MB    | #4         |  14%
# numba-0.58.0         | 4.3 MB    | #7         |  18%
# numba-0.58.0         | 4.3 MB    | ##1        |  22%
# numba-0.58.0         | 4.3 MB    | ##5        |  26%
# numba-0.58.0         | 4.3 MB    | ##9        |  29%
# numba-0.58.0         | 4.3 MB    | ###2       |  33%
# numba-0.58.0         | 4.3 MB    | ###6       |  36%
# numba-0.58.0         | 4.3 MB    | ###9       |  40%
# numba-0.58.0         | 4.3 MB    | ####3      |  44%
# numba-0.58.0         | 4.3 MB    | ####7      |  48%
# numba-0.58.0         | 4.3 MB    | #####1     |  51%
# numba-0.58.0         | 4.3 MB    | #####5     |  55%
# numba-0.58.0         | 4.3 MB    | #####9     |  59%
# numba-0.58.0         | 4.3 MB    | ######3    |  63%
# numba-0.58.0         | 4.3 MB    | ######6    |  67%
# numba-0.58.0         | 4.3 MB    | #######    |  71%
# numba-0.58.0         | 4.3 MB    | #######4   |  75%
# numba-0.58.0         | 4.3 MB    | #######8   |  78%
# numba-0.58.0         | 4.3 MB    | ########2  |  82%
# numba-0.58.0         | 4.3 MB    | ########5  |  85%
# numba-0.58.0         | 4.3 MB    | ########8  |  89%
# numba-0.58.0         | 4.3 MB    | #########3 |  94%
# numba-0.58.0         | 4.3 MB    | #########7 |  97%
# numba-0.58.0         | 4.3 MB    | ########## | 100%
#
# imageio-2.31.4       | 479 KB    |            |   0%
# imageio-2.31.4       | 479 KB    | 3          |   3%
# imageio-2.31.4       | 479 KB    | ####       |  40%
# imageio-2.31.4       | 479 KB    | ######3    |  63%
# imageio-2.31.4       | 479 KB    | ########3  |  84%
# imageio-2.31.4       | 479 KB    | #########6 |  97%
# imageio-2.31.4       | 479 KB    | ########## | 100%
#
# boltons-23.0.0       | 421 KB    |            |   0%
# boltons-23.0.0       | 421 KB    | #8         |  19%
# boltons-23.0.0       | 421 KB    | #####6     |  57%
# boltons-23.0.0       | 421 KB    | #########1 |  91%
# boltons-23.0.0       | 421 KB    | ########## | 100%
#
# y-py-0.5.9           | 61.5 MB   |            |   0%
# y-py-0.5.9           | 61.5 MB   |            |   0%
# y-py-0.5.9           | 61.5 MB   |            |   0%
# y-py-0.5.9           | 61.5 MB   |            |   1%
# y-py-0.5.9           | 61.5 MB   |            |   1%
# y-py-0.5.9           | 61.5 MB   |            |   1%
# y-py-0.5.9           | 61.5 MB   | 1          |   1%
# y-py-0.5.9           | 61.5 MB   | 1          |   1%
# y-py-0.5.9           | 61.5 MB   | 1          |   1%
# y-py-0.5.9           | 61.5 MB   | 1          |   2%
# y-py-0.5.9           | 61.5 MB   | 1          |   2%
# y-py-0.5.9           | 61.5 MB   | 1          |   2%
# y-py-0.5.9           | 61.5 MB   | 2          |   2%
# y-py-0.5.9           | 61.5 MB   | 2          |   2%
# y-py-0.5.9           | 61.5 MB   | 2          |   3%
# y-py-0.5.9           | 61.5 MB   | 2          |   3%
# y-py-0.5.9           | 61.5 MB   | 2          |   3%
# y-py-0.5.9           | 61.5 MB   | 3          |   3%
# y-py-0.5.9           | 61.5 MB   | 3          |   3%
# y-py-0.5.9           | 61.5 MB   | 3          |   4%
# y-py-0.5.9           | 61.5 MB   | 3          |   4%
# y-py-0.5.9           | 61.5 MB   | 4          |   4%
# y-py-0.5.9           | 61.5 MB   | 4          |   4%
# y-py-0.5.9           | 61.5 MB   | 4          |   5%
# y-py-0.5.9           | 61.5 MB   | 4          |   5%
# y-py-0.5.9           | 61.5 MB   | 5          |   5%
# y-py-0.5.9           | 61.5 MB   | 5          |   5%
# y-py-0.5.9           | 61.5 MB   | 5          |   6%
# y-py-0.5.9           | 61.5 MB   | 5          |   6%
# y-py-0.5.9           | 61.5 MB   | 5          |   6%
# y-py-0.5.9           | 61.5 MB   | 6          |   6%
# y-py-0.5.9           | 61.5 MB   | 6          |   7%
# y-py-0.5.9           | 61.5 MB   | 6          |   7%
# y-py-0.5.9           | 61.5 MB   | 7          |   7%
# y-py-0.5.9           | 61.5 MB   | 7          |   7%
# y-py-0.5.9           | 61.5 MB   | 7          |   8%
# y-py-0.5.9           | 61.5 MB   | 7          |   8%
# y-py-0.5.9           | 61.5 MB   | 8          |   8%
# y-py-0.5.9           | 61.5 MB   | 8          |   8%
# y-py-0.5.9           | 61.5 MB   | 8          |   9%
# y-py-0.5.9           | 61.5 MB   | 9          |   9%
# y-py-0.5.9           | 61.5 MB   | 9          |   9%
# y-py-0.5.9           | 61.5 MB   | 9          |  10%
# y-py-0.5.9           | 61.5 MB   | 9          |  10%
# y-py-0.5.9           | 61.5 MB   | #          |  10%
# y-py-0.5.9           | 61.5 MB   | #          |  11%
# y-py-0.5.9           | 61.5 MB   | #          |  11%
# y-py-0.5.9           | 61.5 MB   | #1         |  11%
# y-py-0.5.9           | 61.5 MB   | #1         |  11%
# y-py-0.5.9           | 61.5 MB   | #1         |  12%
# y-py-0.5.9           | 61.5 MB   | #2         |  12%
# y-py-0.5.9           | 61.5 MB   | #2         |  12%
# y-py-0.5.9           | 61.5 MB   | #2         |  13%
# y-py-0.5.9           | 61.5 MB   | #2         |  13%
# y-py-0.5.9           | 61.5 MB   | #3         |  13%
# y-py-0.5.9           | 61.5 MB   | #3         |  13%
# y-py-0.5.9           | 61.5 MB   | #3         |  14%
# y-py-0.5.9           | 61.5 MB   | #4         |  14%
# y-py-0.5.9           | 61.5 MB   | #4         |  14%
# y-py-0.5.9           | 61.5 MB   | #4         |  15%
# y-py-0.5.9           | 61.5 MB   | #4         |  15%
# y-py-0.5.9           | 61.5 MB   | #5         |  15%
# y-py-0.5.9           | 61.5 MB   | #5         |  15%
# y-py-0.5.9           | 61.5 MB   | #5         |  16%
# y-py-0.5.9           | 61.5 MB   | #6         |  16%
# y-py-0.5.9           | 61.5 MB   | #6         |  16%
# y-py-0.5.9           | 61.5 MB   | #6         |  16%
# y-py-0.5.9           | 61.5 MB   | #6         |  17%
# y-py-0.5.9           | 61.5 MB   | #6         |  17%
# y-py-0.5.9           | 61.5 MB   | #7         |  17%
# y-py-0.5.9           | 61.5 MB   | #7         |  17%
# y-py-0.5.9           | 61.5 MB   | #7         |  18%
# y-py-0.5.9           | 61.5 MB   | #7         |  18%
# y-py-0.5.9           | 61.5 MB   | #8         |  18%
# y-py-0.5.9           | 61.5 MB   | #8         |  18%
# y-py-0.5.9           | 61.5 MB   | #8         |  19%
# y-py-0.5.9           | 61.5 MB   | #9         |  19%
# y-py-0.5.9           | 61.5 MB   | #9         |  19%
# y-py-0.5.9           | 61.5 MB   | #9         |  20%
# y-py-0.5.9           | 61.5 MB   | #9         |  20%
# y-py-0.5.9           | 61.5 MB   | ##         |  20%
# y-py-0.5.9           | 61.5 MB   | ##         |  20%
# y-py-0.5.9           | 61.5 MB   | ##         |  21%
# y-py-0.5.9           | 61.5 MB   | ##         |  21%
# y-py-0.5.9           | 61.5 MB   | ##1        |  21%
# y-py-0.5.9           | 61.5 MB   | ##1        |  21%
# y-py-0.5.9           | 61.5 MB   | ##1        |  22%
# y-py-0.5.9           | 61.5 MB   | ##2        |  22%
# y-py-0.5.9           | 61.5 MB   | ##2        |  22%
# y-py-0.5.9           | 61.5 MB   | ##2        |  23%
# y-py-0.5.9           | 61.5 MB   | ##2        |  23%
# y-py-0.5.9           | 61.5 MB   | ##3        |  23%
# y-py-0.5.9           | 61.5 MB   | ##3        |  23%
# y-py-0.5.9           | 61.5 MB   | ##3        |  24%
# y-py-0.5.9           | 61.5 MB   | ##3        |  24%
# y-py-0.5.9           | 61.5 MB   | ##4        |  24%
# y-py-0.5.9           | 61.5 MB   | ##4        |  24%
# y-py-0.5.9           | 61.5 MB   | ##4        |  25%
# y-py-0.5.9           | 61.5 MB   | ##4        |  25%
# y-py-0.5.9           | 61.5 MB   | ##4        |  25%
# y-py-0.5.9           | 61.5 MB   | ##5        |  25%
# y-py-0.5.9           | 61.5 MB   | ##5        |  25%
# y-py-0.5.9           | 61.5 MB   | ##5        |  26%
# y-py-0.5.9           | 61.5 MB   | ##5        |  26%
# y-py-0.5.9           | 61.5 MB   | ##6        |  26%
# y-py-0.5.9           | 61.5 MB   | ##6        |  26%
# y-py-0.5.9           | 61.5 MB   | ##6        |  26%
# y-py-0.5.9           | 61.5 MB   | ##6        |  27%
# y-py-0.5.9           | 61.5 MB   | ##6        |  27%
# y-py-0.5.9           | 61.5 MB   | ##7        |  27%
# y-py-0.5.9           | 61.5 MB   | ##7        |  27%
# y-py-0.5.9           | 61.5 MB   | ##7        |  28%
# y-py-0.5.9           | 61.5 MB   | ##7        |  28%
# y-py-0.5.9           | 61.5 MB   | ##8        |  28%
# y-py-0.5.9           | 61.5 MB   | ##8        |  28%
# y-py-0.5.9           | 61.5 MB   | ##8        |  28%
# y-py-0.5.9           | 61.5 MB   | ##8        |  29%
# y-py-0.5.9           | 61.5 MB   | ##8        |  29%
# y-py-0.5.9           | 61.5 MB   | ##9        |  29%
# y-py-0.5.9           | 61.5 MB   | ##9        |  29%
# y-py-0.5.9           | 61.5 MB   | ##9        |  29%
# y-py-0.5.9           | 61.5 MB   | ##9        |  30%
# y-py-0.5.9           | 61.5 MB   | ##9        |  30%
# y-py-0.5.9           | 61.5 MB   | ###        |  30%
# y-py-0.5.9           | 61.5 MB   | ###        |  30%
# y-py-0.5.9           | 61.5 MB   | ###        |  31%
# y-py-0.5.9           | 61.5 MB   | ###        |  31%
# y-py-0.5.9           | 61.5 MB   | ###        |  31%
# y-py-0.5.9           | 61.5 MB   | ###1       |  31%
# y-py-0.5.9           | 61.5 MB   | ###1       |  31%
# y-py-0.5.9           | 61.5 MB   | ###1       |  32%
# y-py-0.5.9           | 61.5 MB   | ###1       |  32%
# y-py-0.5.9           | 61.5 MB   | ###2       |  32%
# y-py-0.5.9           | 61.5 MB   | ###2       |  32%
# y-py-0.5.9           | 61.5 MB   | ###2       |  33%
# y-py-0.5.9           | 61.5 MB   | ###2       |  33%
# y-py-0.5.9           | 61.5 MB   | ###2       |  33%
# y-py-0.5.9           | 61.5 MB   | ###3       |  33%
# y-py-0.5.9           | 61.5 MB   | ###3       |  33%
# y-py-0.5.9           | 61.5 MB   | ###3       |  34%
# y-py-0.5.9           | 61.5 MB   | ###3       |  34%
# y-py-0.5.9           | 61.5 MB   | ###4       |  34%
# y-py-0.5.9           | 61.5 MB   | ###4       |  34%
# y-py-0.5.9           | 61.5 MB   | ###4       |  34%
# y-py-0.5.9           | 61.5 MB   | ###4       |  35%
# y-py-0.5.9           | 61.5 MB   | ###4       |  35%
# y-py-0.5.9           | 61.5 MB   | ###5       |  35%
# y-py-0.5.9           | 61.5 MB   | ###5       |  35%
# y-py-0.5.9           | 61.5 MB   | ###5       |  36%
# y-py-0.5.9           | 61.5 MB   | ###5       |  36%
# y-py-0.5.9           | 61.5 MB   | ###5       |  36%
# y-py-0.5.9           | 61.5 MB   | ###6       |  36%
# y-py-0.5.9           | 61.5 MB   | ###6       |  36%
# y-py-0.5.9           | 61.5 MB   | ###6       |  37%
# y-py-0.5.9           | 61.5 MB   | ###6       |  37%
# y-py-0.5.9           | 61.5 MB   | ###7       |  37%
# y-py-0.5.9           | 61.5 MB   | ###7       |  37%
# y-py-0.5.9           | 61.5 MB   | ###7       |  37%
# y-py-0.5.9           | 61.5 MB   | ###7       |  38%
# y-py-0.5.9           | 61.5 MB   | ###7       |  38%
# y-py-0.5.9           | 61.5 MB   | ###7       |  38%
# y-py-0.5.9           | 61.5 MB   | ###8       |  38%
# y-py-0.5.9           | 61.5 MB   | ###8       |  38%
# y-py-0.5.9           | 61.5 MB   | ###8       |  39%
# y-py-0.5.9           | 61.5 MB   | ###8       |  39%
# y-py-0.5.9           | 61.5 MB   | ###8       |  39%
# y-py-0.5.9           | 61.5 MB   | ###9       |  39%
# y-py-0.5.9           | 61.5 MB   | ###9       |  39%
# y-py-0.5.9           | 61.5 MB   | ###9       |  40%
# y-py-0.5.9           | 61.5 MB   | ###9       |  40%
# y-py-0.5.9           | 61.5 MB   | ####       |  40%
# y-py-0.5.9           | 61.5 MB   | ####       |  40%
# y-py-0.5.9           | 61.5 MB   | ####       |  41%
# y-py-0.5.9           | 61.5 MB   | ####       |  41%
# y-py-0.5.9           | 61.5 MB   | ####1      |  41%
# y-py-0.5.9           | 61.5 MB   | ####1      |  41%
# y-py-0.5.9           | 61.5 MB   | ####1      |  42%
# y-py-0.5.9           | 61.5 MB   | ####1      |  42%
# y-py-0.5.9           | 61.5 MB   | ####2      |  42%
# y-py-0.5.9           | 61.5 MB   | ####2      |  42%
# y-py-0.5.9           | 61.5 MB   | ####2      |  43%
# y-py-0.5.9           | 61.5 MB   | ####2      |  43%
# y-py-0.5.9           | 61.5 MB   | ####2      |  43%
# y-py-0.5.9           | 61.5 MB   | ####3      |  43%
# y-py-0.5.9           | 61.5 MB   | ####3      |  43%
# y-py-0.5.9           | 61.5 MB   | ####3      |  44%
# y-py-0.5.9           | 61.5 MB   | ####3      |  44%
# y-py-0.5.9           | 61.5 MB   | ####4      |  44%
# y-py-0.5.9           | 61.5 MB   | ####4      |  44%
# y-py-0.5.9           | 61.5 MB   | ####4      |  44%
# y-py-0.5.9           | 61.5 MB   | ####4      |  45%
# y-py-0.5.9           | 61.5 MB   | ####5      |  45%
# y-py-0.5.9           | 61.5 MB   | ####5      |  45%
# y-py-0.5.9           | 61.5 MB   | ####5      |  46%
# y-py-0.5.9           | 61.5 MB   | ####5      |  46%
# y-py-0.5.9           | 61.5 MB   | ####6      |  46%
# y-py-0.5.9           | 61.5 MB   | ####6      |  46%
# y-py-0.5.9           | 61.5 MB   | ####6      |  47%
# y-py-0.5.9           | 61.5 MB   | ####6      |  47%
# y-py-0.5.9           | 61.5 MB   | ####7      |  47%
# y-py-0.5.9           | 61.5 MB   | ####7      |  47%
# y-py-0.5.9           | 61.5 MB   | ####7      |  48%
# y-py-0.5.9           | 61.5 MB   | ####7      |  48%
# y-py-0.5.9           | 61.5 MB   | ####8      |  48%
# y-py-0.5.9           | 61.5 MB   | ####8      |  48%
# y-py-0.5.9           | 61.5 MB   | ####8      |  49%
# y-py-0.5.9           | 61.5 MB   | ####8      |  49%
# y-py-0.5.9           | 61.5 MB   | ####8      |  49%
# y-py-0.5.9           | 61.5 MB   | ####9      |  49%
# y-py-0.5.9           | 61.5 MB   | ####9      |  49%
# y-py-0.5.9           | 61.5 MB   | ####9      |  50%
# y-py-0.5.9           | 61.5 MB   | ####9      |  50%
# y-py-0.5.9           | 61.5 MB   | #####      |  50%
# y-py-0.5.9           | 61.5 MB   | #####      |  50%
# y-py-0.5.9           | 61.5 MB   | #####      |  50%
# y-py-0.5.9           | 61.5 MB   | #####      |  50%
# y-py-0.5.9           | 61.5 MB   | #####      |  51%
# y-py-0.5.9           | 61.5 MB   | #####      |  51%
# y-py-0.5.9           | 61.5 MB   | #####1     |  51%
# y-py-0.5.9           | 61.5 MB   | #####1     |  51%
# y-py-0.5.9           | 61.5 MB   | #####1     |  51%
# y-py-0.5.9           | 61.5 MB   | #####1     |  52%
# y-py-0.5.9           | 61.5 MB   | #####1     |  52%
# y-py-0.5.9           | 61.5 MB   | #####2     |  52%
# y-py-0.5.9           | 61.5 MB   | #####2     |  52%
# y-py-0.5.9           | 61.5 MB   | #####2     |  53%
# y-py-0.5.9           | 61.5 MB   | #####2     |  53%
# y-py-0.5.9           | 61.5 MB   | #####3     |  53%
# y-py-0.5.9           | 61.5 MB   | #####3     |  53%
# y-py-0.5.9           | 61.5 MB   | #####3     |  53%
# y-py-0.5.9           | 61.5 MB   | #####3     |  54%
# y-py-0.5.9           | 61.5 MB   | #####4     |  54%
# y-py-0.5.9           | 61.5 MB   | #####4     |  54%
# y-py-0.5.9           | 61.5 MB   | #####4     |  55%
# y-py-0.5.9           | 61.5 MB   | #####4     |  55%
# y-py-0.5.9           | 61.5 MB   | #####5     |  55%
# y-py-0.5.9           | 61.5 MB   | #####5     |  55%
# y-py-0.5.9           | 61.5 MB   | #####5     |  56%
# y-py-0.5.9           | 61.5 MB   | #####5     |  56%
# y-py-0.5.9           | 61.5 MB   | #####6     |  56%
# y-py-0.5.9           | 61.5 MB   | #####6     |  57%
# y-py-0.5.9           | 61.5 MB   | #####6     |  57%
# y-py-0.5.9           | 61.5 MB   | #####7     |  57%
# y-py-0.5.9           | 61.5 MB   | #####7     |  57%
# y-py-0.5.9           | 61.5 MB   | #####7     |  58%
# y-py-0.5.9           | 61.5 MB   | #####7     |  58%
# y-py-0.5.9           | 61.5 MB   | #####8     |  58%
# y-py-0.5.9           | 61.5 MB   | #####8     |  58%
# y-py-0.5.9           | 61.5 MB   | #####8     |  59%
# y-py-0.5.9           | 61.5 MB   | #####8     |  59%
# y-py-0.5.9           | 61.5 MB   | #####9     |  59%
# y-py-0.5.9           | 61.5 MB   | #####9     |  59%
# y-py-0.5.9           | 61.5 MB   | #####9     |  60%
# y-py-0.5.9           | 61.5 MB   | #####9     |  60%
# y-py-0.5.9           | 61.5 MB   | ######     |  60%
# y-py-0.5.9           | 61.5 MB   | ######     |  60%
# y-py-0.5.9           | 61.5 MB   | ######     |  61%
# y-py-0.5.9           | 61.5 MB   | ######     |  61%
# y-py-0.5.9           | 61.5 MB   | ######     |  61%
# y-py-0.5.9           | 61.5 MB   | ######1    |  61%
# y-py-0.5.9           | 61.5 MB   | ######1    |  61%
# y-py-0.5.9           | 61.5 MB   | ######1    |  62%
# y-py-0.5.9           | 61.5 MB   | ######1    |  62%
# y-py-0.5.9           | 61.5 MB   | ######2    |  62%
# y-py-0.5.9           | 61.5 MB   | ######2    |  62%
# y-py-0.5.9           | 61.5 MB   | ######2    |  63%
# y-py-0.5.9           | 61.5 MB   | ######2    |  63%
# y-py-0.5.9           | 61.5 MB   | ######3    |  63%
# y-py-0.5.9           | 61.5 MB   | ######3    |  63%
# y-py-0.5.9           | 61.5 MB   | ######3    |  64%
# y-py-0.5.9           | 61.5 MB   | ######3    |  64%
# y-py-0.5.9           | 61.5 MB   | ######3    |  64%
# y-py-0.5.9           | 61.5 MB   | ######4    |  64%
# y-py-0.5.9           | 61.5 MB   | ######4    |  64%
# y-py-0.5.9           | 61.5 MB   | ######4    |  65%
# y-py-0.5.9           | 61.5 MB   | ######4    |  65%
# y-py-0.5.9           | 61.5 MB   | ######5    |  65%
# y-py-0.5.9           | 61.5 MB   | ######5    |  65%
# y-py-0.5.9           | 61.5 MB   | ######5    |  66%
# y-py-0.5.9           | 61.5 MB   | ######5    |  66%
# y-py-0.5.9           | 61.5 MB   | ######6    |  66%
# y-py-0.5.9           | 61.5 MB   | ######6    |  66%
# y-py-0.5.9           | 61.5 MB   | ######6    |  67%
# y-py-0.5.9           | 61.5 MB   | ######7    |  67%
# y-py-0.5.9           | 61.5 MB   | ######7    |  67%
# y-py-0.5.9           | 61.5 MB   | ######7    |  68%
# y-py-0.5.9           | 61.5 MB   | ######7    |  68%
# y-py-0.5.9           | 61.5 MB   | ######8    |  68%
# y-py-0.5.9           | 61.5 MB   | ######8    |  68%
# y-py-0.5.9           | 61.5 MB   | ######8    |  69%
#
# y-py-0.5.9           | 61.5 MB   | ######8    |  69%
# y-py-0.5.9           | 61.5 MB   | ######9    |  69%
# y-py-0.5.9           | 61.5 MB   | ######9    |  69%
# y-py-0.5.9           | 61.5 MB   | ######9    |  69%
# y-py-0.5.9           | 61.5 MB   | ######9    |  70%
# y-py-0.5.9           | 61.5 MB   | ######9    |  70%
# y-py-0.5.9           | 61.5 MB   | #######    |  70%
# y-py-0.5.9           | 61.5 MB   | #######    |  70%
# y-py-0.5.9           | 61.5 MB   | #######    |  71%
# y-py-0.5.9           | 61.5 MB   | #######    |  71%
# y-py-0.5.9           | 61.5 MB   | #######1   |  71%
# y-py-0.5.9           | 61.5 MB   | #######1   |  72%
# y-py-0.5.9           | 61.5 MB   | #######1   |  72%
# y-py-0.5.9           | 61.5 MB   | #######2   |  72%
# y-py-0.5.9           | 61.5 MB   | #######2   |  72%
# y-py-0.5.9           | 61.5 MB   | #######2   |  73%
# y-py-0.5.9           | 61.5 MB   | #######3   |  73%
# y-py-0.5.9           | 61.5 MB   | #######3   |  73%
# y-py-0.5.9           | 61.5 MB   | #######3   |  74%
# y-py-0.5.9           | 61.5 MB   | #######3   |  74%
# y-py-0.5.9           | 61.5 MB   | #######4   |  74%
# y-py-0.5.9           | 61.5 MB   | #######4   |  74%
# y-py-0.5.9           | 61.5 MB   | #######4   |  75%
# y-py-0.5.9           | 61.5 MB   | #######4   |  75%
# y-py-0.5.9           | 61.5 MB   | #######5   |  75%
# y-py-0.5.9           | 61.5 MB   | #######5   |  75%
# y-py-0.5.9           | 61.5 MB   | #######5   |  76%
# y-py-0.5.9           | 61.5 MB   | #######5   |  76%
# y-py-0.5.9           | 61.5 MB   | #######6   |  76%
# y-py-0.5.9           | 61.5 MB   | #######6   |  77%
# y-py-0.5.9           | 61.5 MB   | #######6   |  77%
# y-py-0.5.9           | 61.5 MB   | #######7   |  77%
# y-py-0.5.9           | 61.5 MB   | #######7   |  77%
# y-py-0.5.9           | 61.5 MB   | #######7   |  78%
# y-py-0.5.9           | 61.5 MB   | #######8   |  78%
# y-py-0.5.9           | 61.5 MB   | #######8   |  78%
# y-py-0.5.9           | 61.5 MB   | #######8   |  79%
# y-py-0.5.9           | 61.5 MB   | #######8   |  79%
# ...
# libboost-1.82.0      | 23.1 MB   | ####1      |  41%
# libboost-1.82.0      | 23.1 MB   | ####2      |  42%
# libboost-1.82.0      | 23.1 MB   | ####2      |  43%
# libboost-1.82.0      | 23.1 MB   | ####3      |  43%
# libboost-1.82.0      | 23.1 MB   | ####3      |  44%
# libboost-1.82.0      | 23.1 MB   | ####4      |  45%
# libboost-1.82.0      | 23.1 MB   | ####5      |  45%
# libboost-1.82.0      | 23.1 MB   | ####5      |  46%
# libboost-1.82.0      | 23.1 MB   | ####6      |  47%
# libboost-1.82.0      | 23.1 MB   | ####7      |  48%
# libboost-1.82.0      | 23.1 MB   | ####8      |  48%
# libboost-1.82.0      | 23.1 MB   | ####9      |  49%
# libboost-1.82.0      | 23.1 MB   | #####      |  50%
# libboost-1.82.0      | 23.1 MB   | #####      |  51%
# libboost-1.82.0      | 23.1 MB   | #####1     |  52%
# libboost-1.82.0      | 23.1 MB   | #####2     |  53%
# libboost-1.82.0      | 23.1 MB   | #####3     |  54%
# libboost-1.82.0      | 23.1 MB   | #####4     |  55%
# libboost-1.82.0      | 23.1 MB   | #####5     |  55%
# libboost-1.82.0      | 23.1 MB   | #####6     |  56%
# libboost-1.82.0      | 23.1 MB   | #####6     |  57%
# libboost-1.82.0      | 23.1 MB   | #####7     |  58%
# libboost-1.82.0      | 23.1 MB   | #####8     |  58%
# libboost-1.82.0      | 23.1 MB   | #####9     |  60%
# libboost-1.82.0      | 23.1 MB   | ######     |  60%
# libboost-1.82.0      | 23.1 MB   | ######1    |  61%
# libboost-1.82.0      | 23.1 MB   | ######1    |  62%
# libboost-1.82.0      | 23.1 MB   | ######2    |  63%
# libboost-1.82.0      | 23.1 MB   | ######3    |  63%
# libboost-1.82.0      | 23.1 MB   | ######3    |  64%
# libboost-1.82.0      | 23.1 MB   | ######4    |  64%
# libboost-1.82.0      | 23.1 MB   | ######5    |  65%
# libboost-1.82.0      | 23.1 MB   | ######5    |  66%
# libboost-1.82.0      | 23.1 MB   | ######6    |  67%
# libboost-1.82.0      | 23.1 MB   | ######7    |  67%
# libboost-1.82.0      | 23.1 MB   | ######8    |  68%
# libboost-1.82.0      | 23.1 MB   | ######9    |  69%
# libboost-1.82.0      | 23.1 MB   | #######    |  70%
# libboost-1.82.0      | 23.1 MB   | #######    |  71%
# libboost-1.82.0      | 23.1 MB   | #######1   |  72%
# libboost-1.82.0      | 23.1 MB   | #######2   |  72%
# libboost-1.82.0      | 23.1 MB   | #######3   |  73%
# libboost-1.82.0      | 23.1 MB   | #######3   |  74%
# libboost-1.82.0      | 23.1 MB   | #######4   |  75%
# libboost-1.82.0      | 23.1 MB   | #######5   |  75%
# libboost-1.82.0      | 23.1 MB   | #######5   |  76%
# libboost-1.82.0      | 23.1 MB   | #######6   |  77%
# libboost-1.82.0      | 23.1 MB   | #######7   |  77%
# libboost-1.82.0      | 23.1 MB   | #######7   |  78%
# libboost-1.82.0      | 23.1 MB   | #######8   |  79%
# libboost-1.82.0      | 23.1 MB   | #######9   |  79%
# libboost-1.82.0      | 23.1 MB   | ########   |  80%
# libboost-1.82.0      | 23.1 MB   | ########   |  81%
# libboost-1.82.0      | 23.1 MB   | ########1  |  82%
# libboost-1.82.0      | 23.1 MB   | ########2  |  82%
# libboost-1.82.0      | 23.1 MB   | ########3  |  83%
# libboost-1.82.0      | 23.1 MB   | ########3  |  84%
# libboost-1.82.0      | 23.1 MB   | ########4  |  85%
# libboost-1.82.0      | 23.1 MB   | ########5  |  86%
# libboost-1.82.0      | 23.1 MB   | ########6  |  86%
# libboost-1.82.0      | 23.1 MB   | ########7  |  87%
# libboost-1.82.0      | 23.1 MB   | ########7  |  88%
# libboost-1.82.0      | 23.1 MB   | ########8  |  89%
# libboost-1.82.0      | 23.1 MB   | ########9  |  90%
# libboost-1.82.0      | 23.1 MB   | #########  |  90%
# libboost-1.82.0      | 23.1 MB   | #########1 |  91%
# libboost-1.82.0      | 23.1 MB   | #########1 |  92%
# libboost-1.82.0      | 23.1 MB   | #########2 |  93%
# libboost-1.82.0      | 23.1 MB   | #########3 |  94%
# libboost-1.82.0      | 23.1 MB   | #########4 |  94%
# libboost-1.82.0      | 23.1 MB   | #########5 |  95%
# libboost-1.82.0      | 23.1 MB   | #########5 |  96%
# libboost-1.82.0      | 23.1 MB   | #########6 |  96%
# libboost-1.82.0      | 23.1 MB   | #########6 |  97%
# libboost-1.82.0      | 23.1 MB   | #########7 |  98%
# libboost-1.82.0      | 23.1 MB   | #########8 |  99%
# libboost-1.82.0      | 23.1 MB   | #########9 | 100%
# libboost-1.82.0      | 23.1 MB   | ########## | 100%
#
# aiosqlite-0.18.0     | 34 KB     |            |   0%
# aiosqlite-0.18.0     | 34 KB     | ####7      |  47%
# aiosqlite-0.18.0     | 34 KB     | ########## | 100%
# aiosqlite-0.18.0     | 34 KB     | ########## | 100%
#
# boost-cpp-1.82.0     | 11 KB     |            |   0%
# boost-cpp-1.82.0     | 11 KB     | ########## | 100%
# boost-cpp-1.82.0     | 11 KB     | ########## | 100%
#
# pandas-2.0.3         | 9.8 MB    |            |   0%
# pandas-2.0.3         | 9.8 MB    |            |   0%
# pandas-2.0.3         | 9.8 MB    | 2          |   2%
# pandas-2.0.3         | 9.8 MB    | 3          |   4%
# pandas-2.0.3         | 9.8 MB    | 4          |   5%
# pandas-2.0.3         | 9.8 MB    | 5          |   6%
# pandas-2.0.3         | 9.8 MB    | 6          |   7%
# pandas-2.0.3         | 9.8 MB    | 7          |   8%
# pandas-2.0.3         | 9.8 MB    | 9          |   9%
# pandas-2.0.3         | 9.8 MB    | #          |  10%
# pandas-2.0.3         | 9.8 MB    | #1         |  11%
# pandas-2.0.3         | 9.8 MB    | #1         |  12%
# pandas-2.0.3         | 9.8 MB    | #2         |  13%
# pandas-2.0.3         | 9.8 MB    | #3         |  13%
# pandas-2.0.3         | 9.8 MB    | #4         |  15%
# pandas-2.0.3         | 9.8 MB    | #6         |  16%
# pandas-2.0.3         | 9.8 MB    | #7         |  18%
# pandas-2.0.3         | 9.8 MB    | #9         |  19%
# pandas-2.0.3         | 9.8 MB    | ##         |  21%
# pandas-2.0.3         | 9.8 MB    | ##2        |  22%
# pandas-2.0.3         | 9.8 MB    | ##5        |  25%
# pandas-2.0.3         | 9.8 MB    | ##6        |  27%
# pandas-2.0.3         | 9.8 MB    | ##8        |  29%
# pandas-2.0.3         | 9.8 MB    | ###        |  30%
# pandas-2.0.3         | 9.8 MB    | ###1       |  32%
# pandas-2.0.3         | 9.8 MB    | ###3       |  33%
# pandas-2.0.3         | 9.8 MB    | ###5       |  35%
# pandas-2.0.3         | 9.8 MB    | ###6       |  37%
# pandas-2.0.3         | 9.8 MB    | ###8       |  38%
# pandas-2.0.3         | 9.8 MB    | ###9       |  40%
# pandas-2.0.3         | 9.8 MB    | ####1      |  42%
# pandas-2.0.3         | 9.8 MB    | ####3      |  44%
# pandas-2.0.3         | 9.8 MB    | ####4      |  45%
# pandas-2.0.3         | 9.8 MB    | ####6      |  47%
# pandas-2.0.3         | 9.8 MB    | ####7      |  48%
# pandas-2.0.3         | 9.8 MB    | ####8      |  49%
# pandas-2.0.3         | 9.8 MB    | #####      |  50%
# pandas-2.0.3         | 9.8 MB    | #####1     |  52%
# pandas-2.0.3         | 9.8 MB    | #####3     |  53%
# pandas-2.0.3         | 9.8 MB    | #####4     |  55%
# pandas-2.0.3         | 9.8 MB    | #####6     |  56%
# pandas-2.0.3         | 9.8 MB    | #####7     |  58%
# pandas-2.0.3         | 9.8 MB    | #####9     |  59%
# pandas-2.0.3         | 9.8 MB    | ######     |  61%
# pandas-2.0.3         | 9.8 MB    | ######2    |  62%
# pandas-2.0.3         | 9.8 MB    | ######3    |  64%
# pandas-2.0.3         | 9.8 MB    | ######5    |  65%
# pandas-2.0.3         | 9.8 MB    | ######6    |  67%
# pandas-2.0.3         | 9.8 MB    | ######8    |  68%
# pandas-2.0.3         | 9.8 MB    | ######9    |  70%
# pandas-2.0.3         | 9.8 MB    | #######1   |  72%
# pandas-2.0.3         | 9.8 MB    | #######3   |  73%
# pandas-2.0.3         | 9.8 MB    | #######4   |  75%
# pandas-2.0.3         | 9.8 MB    | #######6   |  76%
# pandas-2.0.3         | 9.8 MB    | #######7   |  78%
# pandas-2.0.3         | 9.8 MB    | #######9   |  79%
# pandas-2.0.3         | 9.8 MB    | ########   |  81%
# pandas-2.0.3         | 9.8 MB    | ########2  |  82%
# pandas-2.0.3         | 9.8 MB    | ########3  |  84%
# pandas-2.0.3         | 9.8 MB    | ########4  |  85%
# pandas-2.0.3         | 9.8 MB    | ########6  |  87%
# pandas-2.0.3         | 9.8 MB    | ########8  |  88%
# pandas-2.0.3         | 9.8 MB    | ########9  |  90%
# pandas-2.0.3         | 9.8 MB    | #########1 |  91%
# pandas-2.0.3         | 9.8 MB    | #########2 |  93%
# pandas-2.0.3         | 9.8 MB    | #########4 |  94%
# pandas-2.0.3         | 9.8 MB    | #########6 |  96%
# pandas-2.0.3         | 9.8 MB    | #########7 |  97%
# pandas-2.0.3         | 9.8 MB    | #########9 | 100%
# pandas-2.0.3         | 9.8 MB    | ########## | 100%
#
# rfc3986-validator-0. | 10 KB     |            |   0%
# rfc3986-validator-0. | 10 KB     | ########## | 100%
# rfc3986-validator-0. | 10 KB     | ########## | 100%
#
# jupyter_server-2.5.0 | 486 KB    |            |   0%
# jupyter_server-2.5.0 | 486 KB    | 3          |   3%
# jupyter_server-2.5.0 | 486 KB    | #3         |  13%
# jupyter_server-2.5.0 | 486 KB    | ########2  |  82%
# jupyter_server-2.5.0 | 486 KB    | ########## | 100%
#
# flask-2.2.2          | 165 KB    |            |   0%
# flask-2.2.2          | 165 KB    | #9         |  19%
# flask-2.2.2          | 165 KB    | ########## | 100%
# flask-2.2.2          | 165 KB    | ########## | 100%
#
# regex-2023.10.3      | 326 KB    |            |   0%
# regex-2023.10.3      | 326 KB    | #9         |  20%
# regex-2023.10.3      | 326 KB    | ########3  |  83%
# regex-2023.10.3      | 326 KB    | ########## | 100%
#
# tornado-6.3.3        | 638 KB    |            |   0%
# tornado-6.3.3        | 638 KB    | #2         |  13%
# tornado-6.3.3        | 638 KB    | ####       |  40%
# tornado-6.3.3        | 638 KB    | ######5    |  65%
# tornado-6.3.3        | 638 KB    | #########  |  90%
# tornado-6.3.3        | 638 KB    | ########## | 100%
#
# zict-3.0.0           | 91 KB     |            |   0%
# zict-3.0.0           | 91 KB     | ########## | 100%
# zict-3.0.0           | 91 KB     | ########## | 100%
#
# jsonpatch-1.32       | 15 KB     |            |   0%
# jsonpatch-1.32       | 15 KB     | ########## | 100%
# jsonpatch-1.32       | 15 KB     | ########## | 100%
#
# nbconvert-6.5.4      | 537 KB    |            |   0%
# nbconvert-6.5.4      | 537 KB    | #1         |  12%
# nbconvert-6.5.4      | 537 KB    | ####4      |  45%
# nbconvert-6.5.4      | 537 KB    | #######4   |  75%
# nbconvert-6.5.4      | 537 KB    | ########## | 100%
# nbconvert-6.5.4      | 537 KB    | ########## | 100%
#
# jupyterlab-3.6.3     | 4.3 MB    |            |   0%
# jupyterlab-3.6.3     | 4.3 MB    |            |   0%
# jupyterlab-3.6.3     | 4.3 MB    | 5          |   6%
# jupyterlab-3.6.3     | 4.3 MB    | 9          |  10%
# jupyterlab-3.6.3     | 4.3 MB    | #3         |  14%
# jupyterlab-3.6.3     | 4.3 MB    | #7         |  18%
# jupyterlab-3.6.3     | 4.3 MB    | ##1        |  22%
# jupyterlab-3.6.3     | 4.3 MB    | ##5        |  25%
# jupyterlab-3.6.3     | 4.3 MB    | ##8        |  29%
# jupyterlab-3.6.3     | 4.3 MB    | ###2       |  33%
# jupyterlab-3.6.3     | 4.3 MB    | ###6       |  36%
# jupyterlab-3.6.3     | 4.3 MB    | ###9       |  40%
# jupyterlab-3.6.3     | 4.3 MB    | ####4      |  44%
# jupyterlab-3.6.3     | 4.3 MB    | ####8      |  48%
# jupyterlab-3.6.3     | 4.3 MB    | #####1     |  52%
# jupyterlab-3.6.3     | 4.3 MB    | #####5     |  55%
# jupyterlab-3.6.3     | 4.3 MB    | #####8     |  59%
# jupyterlab-3.6.3     | 4.3 MB    | ######1    |  62%
# jupyterlab-3.6.3     | 4.3 MB    | ######4    |  65%
# jupyterlab-3.6.3     | 4.3 MB    | ######7    |  67%
# jupyterlab-3.6.3     | 4.3 MB    | #######3   |  73%
# jupyterlab-3.6.3     | 4.3 MB    | #######7   |  77%
# jupyterlab-3.6.3     | 4.3 MB    | ########   |  81%
# jupyterlab-3.6.3     | 4.3 MB    | ########4  |  84%
# jupyterlab-3.6.3     | 4.3 MB    | ########7  |  88%
# jupyterlab-3.6.3     | 4.3 MB    | #########1 |  91%
# jupyterlab-3.6.3     | 4.3 MB    | #########5 |  95%
# jupyterlab-3.6.3     | 4.3 MB    | #########9 |  99%
# jupyterlab-3.6.3     | 4.3 MB    | ########## | 100%
#
# aiofiles-22.1.0      | 25 KB     |            |   0%
# aiofiles-22.1.0      | 25 KB     | ########## | 100%
# aiofiles-22.1.0      | 25 KB     | ########## | 100%
#
# ypy-websocket-0.8.2  | 26 KB     |            |   0%
# ypy-websocket-0.8.2  | 26 KB     | ########## | 100%
# ypy-websocket-0.8.2  | 26 KB     | ########## | 100%
#
# conda-index-0.3.0    | 202 KB    |            |   0%
# conda-index-0.3.0    | 202 KB    | ###9       |  40%
# conda-index-0.3.0    | 202 KB    | ########## | 100%
# conda-index-0.3.0    | 202 KB    | ########## | 100%
#
# jinja2-3.1.2         | 211 KB    |            |   0%
# jinja2-3.1.2         | 211 KB    | ###        |  30%
# jinja2-3.1.2         | 211 KB    | ########## | 100%
# jinja2-3.1.2         | 211 KB    | ########## | 100%
#
# pycosat-0.6.6        | 84 KB     |            |   0%
# pycosat-0.6.6        | 84 KB     | #8         |  19%
# pycosat-0.6.6        | 84 KB     | #########4 |  95%
# pycosat-0.6.6        | 84 KB     | ########## | 100%
#
# sqlalchemy-2.0.21    | 3.0 MB    |            |   0%
# sqlalchemy-2.0.21    | 3.0 MB    | 3          |   3%
# sqlalchemy-2.0.21    | 3.0 MB    | 8          |   9%
# sqlalchemy-2.0.21    | 3.0 MB    | #3         |  14%
# sqlalchemy-2.0.21    | 3.0 MB    | ##         |  20%
# sqlalchemy-2.0.21    | 3.0 MB    | ##5        |  25%
# sqlalchemy-2.0.21    | 3.0 MB    | ###2       |  32%
# sqlalchemy-2.0.21    | 3.0 MB    | ###8       |  38%
# sqlalchemy-2.0.21    | 3.0 MB    | ####4      |  44%
# sqlalchemy-2.0.21    | 3.0 MB    | ####9      |  50%
# sqlalchemy-2.0.21    | 3.0 MB    | #####6     |  57%
# sqlalchemy-2.0.21    | 3.0 MB    | ######2    |  62%
# sqlalchemy-2.0.21    | 3.0 MB    | ######7    |  68%
# sqlalchemy-2.0.21    | 3.0 MB    | #######3   |  74%
# sqlalchemy-2.0.21    | 3.0 MB    | #######9   |  79%
# sqlalchemy-2.0.21    | 3.0 MB    | ########4  |  85%
# sqlalchemy-2.0.21    | 3.0 MB    | #########  |  90%
# sqlalchemy-2.0.21    | 3.0 MB    | #########5 |  95%
# sqlalchemy-2.0.21    | 3.0 MB    | ########## | 100%
#
# jsonpointer-2.1      | 9 KB      |            |   0%
# jsonpointer-2.1      | 9 KB      | ########## | 100%
# jsonpointer-2.1      | 9 KB      | ########## | 100%
#
# jupyter_server_termi | 25 KB     |            |   0%
# jupyter_server_termi | 25 KB     | ########## | 100%
# jupyter_server_termi | 25 KB     | ########## | 100%
#
# pillow-10.0.1        | 781 KB    |            |   0%
# pillow-10.0.1        | 781 KB    | 2          |   2%
# pillow-10.0.1        | 781 KB    | #          |  10%
# pillow-10.0.1        | 781 KB    | ##         |  20%
# pillow-10.0.1        | 781 KB    | ####9      |  49%
# pillow-10.0.1        | 781 KB    | ######5    |  66%
# pillow-10.0.1        | 781 KB    | ########6  |  86%
# pillow-10.0.1        | 781 KB    | ########## | 100%
#
# jupyterlab_server-2. | 83 KB     |            |   0%
# jupyterlab_server-2. | 83 KB     | #######7   |  77%
# jupyterlab_server-2. | 83 KB     | ########## | 100%
#
# conda-23.9.0         | 978 KB    |            |   0%
# conda-23.9.0         | 978 KB    | 8          |   8%
# conda-23.9.0         | 978 KB    | #9         |  20%
# conda-23.9.0         | 978 KB    | ###4       |  34%
# conda-23.9.0         | 978 KB    | ####9      |  49%
# conda-23.9.0         | 978 KB    | ######2    |  62%
# conda-23.9.0         | 978 KB    | ########   |  80%
# conda-23.9.0         | 978 KB    | #########6 |  97%
# conda-23.9.0         | 978 KB    | ########## | 100%
#
# pyodbc-4.0.39        | 67 KB     |            |   0%
# pyodbc-4.0.39        | 67 KB     | ####8      |  48%
# pyodbc-4.0.39        | 67 KB     | ########## | 100%
# pyodbc-4.0.39        | 67 KB     | ########## | 100%
#
# jupyter_ydoc-0.2.4   | 15 KB     |            |   0%
# jupyter_ydoc-0.2.4   | 15 KB     | ########## | 100%
# jupyter_ydoc-0.2.4   | 15 KB     | ########## | 100%
#
# werkzeug-2.2.3       | 341 KB    |            |   0%
# werkzeug-2.2.3       | 341 KB    | 9          |   9%
# werkzeug-2.2.3       | 341 KB    | ########9  |  89%
# werkzeug-2.2.3       | 341 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
import lightgbm
print(lightgbm.__version__)
# Out:
# 3.3.5

# %%
pip install bayesian-optimization
# Out:
# Requirement already satisfied: bayesian-optimization in c:\users\dwight jones\anaconda3\lib\site-packages (1.4.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.9.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from bayesian-optimization) (1.24.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from bayesian-optimization) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.18.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from bayesian-optimization) (1.3.0)
# Requirement already satisfied: colorama>=0.4.6 in c:\users\dwight jones\anaconda3\lib\site-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dwight jones\anaconda3\lib\site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (2.2.0)

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\dwight jones\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: graphviz in c:\users\dwight jones\anaconda3\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in c:\users\dwight jones\anaconda3\lib\site-packages (from catboost) (3.7.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from catboost) (1.24.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\dwight jones\anaconda3\lib\site-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in c:\users\dwight jones\anaconda3\lib\site-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in c:\users\dwight jones\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: six in c:\users\dwight jones\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dwight jones\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dwight jones\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dwight jones\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dwight jones\anaconda3\lib\site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\dwight jones\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dwight jones\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from matplotlib->catboost) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\dwight jones\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from matplotlib->catboost) (5.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dwight jones\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd
import lightgbm
from bayes_opt import BayesianOptimization
from catboost import CatBoostClassifier, cv, Pool

# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'Bayesian_optimization_case_study.ipynb',
#  'flight_delays_test.csv.zip',
#  'flight_delays_train.csv.zip']

# %% [markdown]
# ## How does Bayesian optimization work?

# %% [markdown]
# Bayesian optimization works by constructing a posterior distribution of functions (Gaussian process) that best describes the function you want to optimize. As the number of observations grows, the posterior distribution improves, and the algorithm becomes more certain of which regions in parameter space are worth exploring and which are not, as seen in the picture below.

# %% [markdown]
# <img src="https://github.com/fmfn/BayesianOptimization/blob/master/examples/bo_example.png?raw=true" />
# As you iterate over and over, the algorithm balances its needs of exploration and exploitation while taking into account what it knows about the target function. At each step, a Gaussian Process is fitted to the known samples (points previously explored), and the posterior distribution, combined with an exploration strategy (such as UCB — aka Upper Confidence Bound), or EI (Expected Improvement). This process is used to determine the next point that should be explored (see the gif below).
# <img src="https://github.com/fmfn/BayesianOptimization/raw/master/examples/bayesian_optimization.gif" />

# %% [markdown]
# ## Let's look at a simple example

# %% [markdown]
# The first step is to create an optimizer. It uses two items:
# * function to optimize
# * bounds of parameters
#
# The function is the procedure that counts metrics of our model quality. The important thing is that our optimization will maximize the value on function. Smaller metrics are best. Hint: don't forget to use negative metric values.

# %% [markdown]
# Here we define our simple function we want to optimize.

# %%
def simple_func(a, b):
    return a + b

# %% [markdown]
# Now, we define our bounds of the parameters to optimize, within the Bayesian optimizer.

# %%
optimizer = BayesianOptimization(
    simple_func,
    {'a': (1, 3),
    'b': (4, 7)})

# %% [markdown]
# These are the main parameters of this function:
#
# * **n_iter:** This is how many steps of Bayesian optimization you want to perform. The more steps, the more likely you are to find a good maximum.
#
# * **init_points:** This is how many steps of random exploration you want to perform. Random exploration can help by diversifying the exploration space.

# %% [markdown]
# Let's run an example where we use the optimizer to find the best values to maximize the target value for a and b given the inputs of 3 and 2.

# %%
optimizer.maximize(3,2)
# Out:
# |   iter    |  target   |     a     |     b     |
# -------------------------------------------------
# | 1         | 9.303     | 2.982     | 6.321     |
# | 2         | 7.694     | 1.76      | 5.934     |
# | 3         | 6.876     | 2.523     | 4.354     |
# | 4         | 9.327     | 2.999     | 6.328     |
# | 5         | 10.0      | 3.0       | 7.0       |
# =================================================

# %% [markdown]
# Great, now let's print the best parameters and the associated maximized target.

# %%
print(optimizer.max['params']);optimizer.max['target']
# Out:
# {'a': 3.0, 'b': 7.0}
# 10.0

# %% [markdown]
# ## Test it on real data using the Light GBM

# %% [markdown]
# The dataset we will be working with is the famous flight departures dataset. Our modeling goal will be to predict if a flight departure is going to be delayed by 15 minutes based on the other attributes in our dataset. As part of this modeling exercise, we will use Bayesian hyperparameter optimization to identify the best parameters for our model.

# %% [markdown]
# **<font color='teal'> You can load the zipped csv files just as you would regular csv files using Pandas read_csv. In the next cell load the train and test data into two seperate dataframes. </font>**

# %%
train_df = pd.read_csv('flight_delays_train.csv.zip')
test_df = pd.read_csv('flight_delays_test.csv.zip')

# %% [markdown]
# **<font color='teal'> Print the top five rows of the train dataframe and review the columns in the data. </font>**

# %%
train_df.head()
# Out:
#   Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0   c-8       c-21       c-7     1934            AA    ATL  DFW       732
# 1   c-4       c-20       c-3     1548            US    PIT  MCO       834
# 2   c-9        c-2       c-5     1422            XE    RDU  CLE       416
# 3  c-11       c-25       c-6     1015            OO    DEN  MEM       872
# 4  c-10        c-7       c-6     1828            WN    MDW  OMA       423
#
#   dep_delayed_15min
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 Y

# %% [markdown]
# **<font color='teal'> Use the describe function to review the numeric columns in the train dataframe. </font>**

# %%
train_df.describe()
# Out:
#              DepTime      Distance
# count  100000.000000  100000.00000
# mean     1341.523880     729.39716
# std       476.378445     574.61686
# min         1.000000      30.00000
# 25%       931.000000     317.00000
# 50%      1330.000000     575.00000
# 75%      1733.000000     957.00000
# max      2534.000000    4962.00000

# %% [markdown]
# Notice, `DepTime` is the departure time in a numeric representation in 2400 hours.

# %% [markdown]
#  **<font color='teal'>The response variable is 'dep_delayed_15min' which is a categorical column, so we need to map the Y for yes and N for no values to 1 and 0. Run the code in the next cell to do this.</font>**

# %%
#train_df = train_df[train_df.DepTime <= 2400].copy()
y_train = train_df['dep_delayed_15min'].map({'Y': 1, 'N': 0}).values

# %% [markdown]
# ## Feature Engineering
# Use these defined functions to create additional features for the model. Run the cell to add the functions to your workspace.

# %%
def label_enc(df_column):
    df_column = LabelEncoder().fit_transform(df_column)
    return df_column

def make_harmonic_features_sin(value, period=2400):
    value *= 2 * np.pi / period 
    return np.sin(value)

def make_harmonic_features_cos(value, period=2400):
    value *= 2 * np.pi / period 
    return np.cos(value)

def feature_eng(df):
    df['flight'] = df['Origin']+df['Dest']
    df['Month'] = df.Month.map(lambda x: x.split('-')[-1]).astype('int32')
    df['DayofMonth'] = df.DayofMonth.map(lambda x: x.split('-')[-1]).astype('uint8')
    df['begin_of_month'] = (df['DayofMonth'] < 10).astype('uint8')
    df['midddle_of_month'] = ((df['DayofMonth'] >= 10)&(df['DayofMonth'] < 20)).astype('uint8')
    df['end_of_month'] = (df['DayofMonth'] >= 20).astype('uint8')
    df['DayOfWeek'] = df.DayOfWeek.map(lambda x: x.split('-')[-1]).astype('uint8')
    df['hour'] = df.DepTime.map(lambda x: x/100).astype('int32')
    df['morning'] = df['hour'].map(lambda x: 1 if (x <= 11)& (x >= 7) else 0).astype('uint8')
    df['day'] = df['hour'].map(lambda x: 1 if (x >= 12) & (x <= 18) else 0).astype('uint8')
    df['evening'] = df['hour'].map(lambda x: 1 if (x >= 19) & (x <= 23) else 0).astype('uint8')
    df['night'] = df['hour'].map(lambda x: 1 if (x >= 0) & (x <= 6) else 0).astype('int32')
    df['winter'] = df['Month'].map(lambda x: x in [12, 1, 2]).astype('int32')
    df['spring'] = df['Month'].map(lambda x: x in [3, 4, 5]).astype('int32')
    df['summer'] = df['Month'].map(lambda x: x in [6, 7, 8]).astype('int32')
    df['autumn'] = df['Month'].map(lambda x: x in [9, 10, 11]).astype('int32')
    df['holiday'] = (df['DayOfWeek'] >= 5).astype(int) 
    df['weekday'] = (df['DayOfWeek'] < 5).astype(int)
    df['airport_dest_per_month'] = df.groupby(['Dest', 'Month'])['Dest'].transform('count')
    df['airport_origin_per_month'] = df.groupby(['Origin', 'Month'])['Origin'].transform('count')
    df['airport_dest_count'] = df.groupby(['Dest'])['Dest'].transform('count')
    df['airport_origin_count'] = df.groupby(['Origin'])['Origin'].transform('count')
    df['carrier_count'] = df.groupby(['UniqueCarrier'])['Dest'].transform('count')
    df['carrier_count_per month'] = df.groupby(['UniqueCarrier', 'Month'])['Dest'].transform('count')
    df['deptime_cos'] = df['DepTime'].map(make_harmonic_features_cos)
    df['deptime_sin'] = df['DepTime'].map(make_harmonic_features_sin)
    df['flightUC'] = df['flight']+df['UniqueCarrier']
    df['DestUC'] = df['Dest']+df['UniqueCarrier']
    df['OriginUC'] = df['Origin']+df['UniqueCarrier']
    return df.drop('DepTime', axis=1)

# %% [markdown]
# Concatenate the training and testing dataframes.

# %%
full_df = pd.concat([train_df.drop('dep_delayed_15min', axis=1), test_df])
full_df = feature_eng(full_df)

# %% [markdown]
# Apply the earlier defined feature engineering functions to the full dataframe.

# %%
for column in ['UniqueCarrier', 'Origin', 'Dest','flight',  'flightUC', 'DestUC', 'OriginUC']:
    full_df[column] = label_enc(full_df[column])

# %% [markdown]
# Split the new full dataframe into X_train and X_test.

# %%
X_train = full_df[:train_df.shape[0]]
X_test = full_df[train_df.shape[0]:]

# %% [markdown]
# Create a list of the categorical features.

# %%
categorical_features = ['Month',  'DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest','flight',  'flightUC', 'DestUC', 'OriginUC']

# %% [markdown]
# Let's build a light GBM model to test the bayesian optimizer.

# %% [markdown]
# ### [LightGBM](https://lightgbm.readthedocs.io/en/latest/) is a gradient boosting framework that uses tree-based learning algorithms. It is designed to be distributed and efficient with the following advantages:
#
# * Faster training speed and higher efficiency.
# * Lower memory usage.
# * Better accuracy.
# * Support of parallel and GPU learning.
# * Capable of handling large-scale data.

# %% [markdown]
# First, we define the function we want to maximize and that will count cross-validation metrics of lightGBM for our parameters.
#
# Some params such as num_leaves, max_depth, min_child_samples, min_data_in_leaf should be integers.

# %%
def lgb_eval(num_leaves,max_depth,lambda_l2,lambda_l1,min_child_samples, min_data_in_leaf):
    params = {
        "objective" : "binary",
        "metric" : "auc", 
        'is_unbalance': True,
        "num_leaves" : int(num_leaves),
        "max_depth" : int(max_depth),
        "lambda_l2" : lambda_l2,
        "lambda_l1" : lambda_l1,
        "num_threads" : 20,
        "min_child_samples" : int(min_child_samples),
        'min_data_in_leaf': int(min_data_in_leaf),
        "learning_rate" : 0.03,
        "subsample_freq" : 5,
        "bagging_seed" : 42,
        "verbosity" : -1
    }
    lgtrain = lightgbm.Dataset(X_train, y_train,categorical_feature=categorical_features)
    cv_result = lightgbm.cv(params,
                       lgtrain,
                       1000,
                       early_stopping_rounds=100,
                       stratified=True,
                       nfold=3)
    return cv_result['auc-mean'][-1]

# %% [markdown]
# Apply the Bayesian optimizer to the function we created in the previous step to identify the best hyperparameters. We will run 10 iterations and set init_points = 2.

# %%
lgbBO = BayesianOptimization(lgb_eval, {'num_leaves': (25, 4000),
                                                'max_depth': (5, 63),
                                                'lambda_l2': (0.0, 0.05),
                                                'lambda_l1': (0.0, 0.05),
                                                'min_child_samples': (50, 10000),
                                                'min_data_in_leaf': (100, 2000)
                                                })

lgbBO.maximize(n_iter=10, init_points=2)
# Out:
# |   iter    |  target   | lambda_l1 | lambda_l2 | max_depth | min_ch... | min_da... | num_le... |
# -------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] min_data_in_leaf is set=1712, min_child_samples=9463 will be ignored. Current value: min_data_in_leaf=1712
# | 1         | 0.7434    | 0.03863   | 0.00655   | 35.77     | 9.464e+03 | 1.712e+03 | 2.598e+03 |
# | 2         | 0.72      | 0.009599  | 0.01932   | 8.563     | 5.669e+03 | 475.0     | 1.634e+03 |
# | 3         | 0.7248    | 0.01885   | 0.02658   | 59.68     | 6.182e+03 | 621.4     | 448.4     |
# | 4         | 0.743     | 0.01894   | 0.01225   | 54.39     | 8.539e+03 | 1.235e+03 | 3.093e+03 |
# | 5         | 0.7435    | 0.01081   | 0.01618   | 10.91     | 5.627e+03 | 1.936e+03 | 694.8     |
# | 6         | 0.7437    | 0.04723   | 0.0356    | 36.95     | 9.385e+03 | 1.956e+03 | 3.934e+03 |
# | 7         | 0.742     | 0.02715   | 0.01749   | 15.97     | 2.969e+03 | 1.198e+03 | 2.327e+03 |
# | 8         | 0.7254    | 0.0007924 | 0.02684   | 24.95     | 302.5     | 660.4     | 3.892e+03 |
# | 9         | 0.7195    | 0.04276   | 0.03917   | 53.38     | 9.876e+03 | 469.0     | 3.52e+03  |
# | 10        | 0.7437    | 0.02128   | 0.03864   | 16.38     | 8.992e+03 | 1.94e+03  | 3.212e+03 |
# | 11        | 0.7254    | 0.009204  | 0.04294   | 16.8      | 8.154e+03 | 623.5     | 2.978e+03 |
# | 12        | 0.7437    | 0.02907   | 0.03319   | 32.52     | 8.526e+03 | 1.67e+03  | 3.984e+03 |
# =================================================================================================

# %% [markdown]
#  **<font color='teal'> Print the best result by using the '.max' function.</font>**

# %%
lgbBO.max
# Out:
# {'target': 0.7437074772663209,
#  'params': {'lambda_l1': 0.047233538971271014,
#   'lambda_l2': 0.03559868876531687,
#   'max_depth': 36.95274744441939,
#   'min_child_samples': 9385.098888380388,
#   'min_data_in_leaf': 1955.7667565760455,
#   'num_leaves': 3933.952442942651}}

# %% [markdown]
# Review the process at each step by using the '.res[0]' function.

# %%
lgbBO.res[0]
# Out:
# {'target': 0.7434147108775818,
#  'params': {'lambda_l1': 0.038631428456270045,
#   'lambda_l2': 0.006550441377418859,
#   'max_depth': 35.76782125327141,
#   'min_child_samples': 9463.743262298438,
#   'min_data_in_leaf': 1712.0664587582357,
#   'num_leaves': 2597.6376416019957}}
